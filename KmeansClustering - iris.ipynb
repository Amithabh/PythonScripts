# %%
from rpy2.robjects import r
from rpy2.robjects import pandas2ri
def data(name): return pandas2ri.ri2py(r[name])

# imports
# %matplotlib inline

from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from numpy import random, float

# %%
df = data("iris")
df1 = df.iloc[:,0:4]
df.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
model = KMeans(n_clusters=3)

# Note I'm scaling the data to normalize it! Important for good results.
model = model.fit(df1)

# Set the size of the plot
plt.figure(figsize=(14,7))
 
# Create a colormap
colormap = np.array(['red', 'lime', 'black','green'])
 
# Plot Sepal
# The subplot() command specifies numrows, numcols, fignum where fignum ranges from 1 to numrows*numcols.
plt.subplot(1, 2, 1)
plt.scatter(df1['Sepal.Length'], df1['Sepal.Width'], c=colormap[model.labels_],s=40)
plt.title('Sepal')

plt.subplot(1, 2, 2)
plt.scatter(df1['Petal.Length'], df1['Petal.Width'], c=colormap[model.labels_],s=40)
plt.title('Petal')
